# %% [raw]
# # Natural Language Processing
# # A field of AI that allows computers to understand, interpet and generate human language data.
# # Statistics
# # Machine Learning
# # Deep learning

# %% [raw]
# # By leaveraging NLP techniques we can
#
# 1. Save massive amount of time when working with text data.
# 2. Uncover insights that previously might not have been uncovered

# %% [raw]
# # NLP is primarily used for processing and understanding human language.
# While NLP can help with text-based anomaly detection in social media or reviews,
# detecting anomalies in network traffic is more related to network security and involves different algorithms and techniques.
